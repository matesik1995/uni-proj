# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
arr = np.array([
    [ 1,  3,  1,  2],
    [ 1,  2,  5,  8],
    [ 3,  1,  2,  9],
    [ 5,  4,  2,  1]
])
arr = arr[1:3,0:3]

# %%
arr2 = np.array([
    [ 2,  3,  1],
    [ 5,  1,  3]
]).transpose()
arr2
# Out:
# array([[2, 5],
#        [3, 1],
#        [1, 3]])

# %%
arr.dot(arr2)
# Out:
# array([[13, 22],
#        [11, 22]])

# %%
x = np.linspace(-np.pi, np.pi, 100)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %%
x = np.arange(-np.pi, np.pi, np.pi)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %%
x = np.linspace(-np.pi, np.pi, 10)
y = np.sin(x)
plt.plot(x,y)
plt.show()
